# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['species'] = iris.target
iris_df['species'] = iris_df['species'].replace({0: 'setosa', 1: 'versicolor', 2: 'virginica'})


iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
# Summary statistics for numerical columns
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
import seaborn as sns

# loading in titanic dataset
titanic_df = sns.load_dataset('titanic')
titanic_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# summary statistics for numerical columns
titanic_df.describe()

# summary of categorical data
titanic_df.describe(include='object')
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %% [markdown]
# ## Iris Dataset Charts

# %%
# Creating distribution of sepal length using matplotlib
plt.figure(figsize=(8, 6))
plt.hist(iris_df['sepal length (cm)'], bins=15, color='skyblue', edgecolor='black')
plt.title('Distribution of Sepal Length', fontsize=16)
plt.xlabel('Sepal Length (cm)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
# adding in seaborn for boxplot by petal length by species

plt.figure(figsize=(8, 6))
sns.boxplot(x='species', y='petal length (cm)', data=iris_df, palette='pastel')
plt.title('Petal Length by Species', fontsize=16)
plt.xlabel('Species', fontsize=12)
plt.ylabel('Petal Length (cm)', fontsize=12)
plt.show()
# Out:
# /var/folders/r2/6br9_ctx54nbn2dtbpmtqy380000gn/T/ipykernel_22431/2397189028.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='petal length (cm)', data=iris_df, palette='pastel')

# %%
# scatterplot for sepal length vs sepal width.
plt.figure(figsize=(8, 6))
sns.scatterplot(
    x='sepal length (cm)', 
    y='sepal width (cm)', 
    hue='species', 
    style='species', 
    data=iris_df, 
    palette='Set2'
)
plt.title('Sepal Length vs Sepal Width', fontsize=16)
plt.xlabel('Sepal Length (cm)', fontsize=12)
plt.ylabel('Sepal Width (cm)', fontsize=12)
plt.legend(title='Species')
plt.show()

# %% [markdown]
# ## Titanic Dataset Charts

# %%
# survival count histogram
plt.figure(figsize=(8, 6))
sns.countplot(x='survived', data=titanic_df)
plt.title('Survival Count', fontsize=16)
plt.xlabel('Survived (0 = No, 1 = Yes)', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.show()

# %%
# age distribution histogram
plt.figure(figsize=(8, 6))
plt.hist(titanic_df['age'].dropna(), bins=20, color='pink', edgecolor='black')
plt.title('Age Distribution', fontsize=16)
plt.xlabel('Age', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
# countplot - survival by gender using seaborn
plt.figure(figsize=(8, 6))
sns.countplot(x='sex', hue='survived', data=titanic_df, palette='Set2')
plt.title('Survival by Gender', fontsize=16)
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.legend(title='Survived (0 = No, 1 = Yes)')
plt.show()

# %%
# fare by passenger class
plt.figure(figsize=(8, 6))
sns.boxplot(x='class', y='fare', data=titanic_df)
plt.title('Fare by Passenger Class', fontsize=16)
plt.xlabel('Passenger Class', fontsize=12)
plt.ylabel('Fare', fontsize=12)
plt.ylim(0, 300)
plt.show()
